# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('./../data/customer_product_sales.csv')

# %%
data.head()
# Out:
#    CustomerID FirstName   LastName  SalesID  ProductID           ProductName  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    Quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
total_quantity=data.groupby(['CustomerID','ProductName'], as_index=False).agg({'Quantity':'sum'})
total_quantity.head()
# Out:
#    CustomerID                    ProductName  Quantity
# 0          33               Apricots - Dried         1
# 1          33              Assorted Desserts         1
# 2          33        Bandage - Flexible Neon         1
# 3          33  Bar Mix - Pina Colada, 355 Ml         1
# 4          33         Beans - Kidney, Canned         1

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
data_pivotTable=pd.pivot_table(total_quantity, values="Quantity", index=["ProductName"], 
                               columns="CustomerID", fill_value=0)
data_pivotTable
# Out:
# CustomerID                         33     200    264    356    412    464    \
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0      0      0      0
# Apricots - Dried                       1      0      0      0      1      0
# ...                                  ...    ...    ...    ...    ...    ...
# Yeast Dry - Fermipan                   0      0      0      0      0      0
# Yoghurt Tubes                          0      0      0      0      0      0
# Yogurt - Blueberry, 175 Gr             0      1      0      0      0      0
# Yogurt - French Vanilla                1      0      0      1      0      0
# Zucchini - Yellow                      0      0      0      0      0      0
#
# ...

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
data_T=data_pivotTable.T
data_T
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                                   0                                  0
# 200                                  0                                  0
# 264                                  0                                  0
# 356                                  0                                  0
# 412                                  0                                  0
# ...                                ...                                ...
# 97928                                0                                  0
# 98069                                0                                  0
# 98159                                0                                  0
# 98185                                0                                  0
# 98200                                0                                  0
#
# ...

# %%
distance= pd.DataFrame(1/(1 + squareform(pdist(data_T, 'euclidean'))),index=data_pivotTable.columns,
                       columns=data_pivotTable.columns)
distance
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.077421  0.087047  0.081800  0.080634  0.082709
# 200         0.077421  1.000000  0.078448  0.076435  0.073693  0.075255
# 264         0.087047  0.078448  1.000000  0.080070  0.081800  0.080350
# 356         0.081800  0.076435  0.080070  1.000000  0.076435  0.078187
# 412         0.080634  0.073693  0.081800  0.076435  1.000000  0.078711
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.004515  0.004521  0.004543  0.004526  0.004530  0.004533
# 98069       0.004583  0.004614  0.004595  0.004578  0.004578  0.004578
# 98159       0.004355  0.004367  0.004365  0.004365  0.004367  0.004363
# 98185       0.004167  0.004166  0.004179  0.004175  0.004177  0.004167
# 98200       0.004333  0.004335  0.004333  0.004339  0.004349  0.004347
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# ...

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
customer=33
customer_33=distance[customer].sort_values(ascending=False)[1:6]
customer_33
# Out:
# CustomerID
# 3317    0.087047
# 3535    0.087047
# 264     0.087047
# 2503    0.085983
# 3305    0.085638
# Name: 33, dtype: float64

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
customer_33.index
# Out:
# Int64Index([3317, 3535, 264, 2503, 3305], dtype='int64', name='CustomerID')

# %%
total_quantity_example33=total_quantity[total_quantity['CustomerID'].isin(customer_33.index)]
total_quantity_example33
# Out:
#       CustomerID                     ProductName  Quantity
# 131          264               Apricots - Halves         1
# 132          264                  Apricots Fresh         1
# 133          264      Bacardi Breezer - Tropical         1
# 134          264                   Bagel - Plain         1
# 135          264                 Banana - Leaves         1
# ...          ...                             ...       ...
# 3003        3535             Tray - 16in Rnd Blk         1
# 3004        3535                     Wanton Wrap         1
# 3005        3535   Wine - Blue Nun Qualitatswein         1
# 3006        3535  Wine - Magnotta, Merlot Sr Vqa         1
# 3007        3535                   Yoghurt Tubes         1
#
# [270 rows x 3 columns]

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
total_quantity_by_product=total_quantity_example33.groupby(['ProductName'],
                                                            as_index=False).agg({'Quantity':'sum'})
total_quantity_by_product=total_quantity_by_product.sort_values('Quantity',ascending=False)
total_quantity_by_product
# Out:
#                        ProductName  Quantity
# 33               Butter - Unsalted         3
# 203  Wine - Ej Gallo Sierra Valley         3
# 186         Towels - Paper / Kraft         3
# 168   Soup - Campbells Bean Medley         3
# 199  Wine - Blue Nun Qualitatswein         3
# ..                             ...       ...
# 85                Hinge W Undercut         1
# 86   Ice Cream Bar - Hageen Daz To         1
# 87                    Jagermeister         1
# 88       Jolt Cola - Electric Blue         1
# 217        Yogurt - French Vanilla         1
#
# [218 rows x 2 columns]

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
total_quantity33=total_quantity[total_quantity["CustomerID"]==customer]

# %%
all_products=pd.merge(total_quantity_by_product,total_quantity33,
                      how="left",on="ProductName")
all_products
# Out:
#                        ProductName  Quantity_x  CustomerID  Quantity_y
# 0                Butter - Unsalted           3         NaN         NaN
# 1    Wine - Ej Gallo Sierra Valley           3         NaN         NaN
# 2           Towels - Paper / Kraft           3        33.0         1.0
# 3     Soup - Campbells Bean Medley           3         NaN         NaN
# 4    Wine - Blue Nun Qualitatswein           3         NaN         NaN
# ..                             ...         ...         ...         ...
# 213               Hinge W Undercut           1         NaN         NaN
# 214  Ice Cream Bar - Hageen Daz To           1         NaN         NaN
# 215                   Jagermeister           1         NaN         NaN
# 216      Jolt Cola - Electric Blue           1         NaN         NaN
# 217        Yogurt - French Vanilla           1        33.0         1.0
#
# [218 rows x 4 columns]

# %%
non_purchate_products=all_products[all_products['Quantity_y'].isnull()].sort_values('Quantity_x',ascending=False)[0:5]
non_purchate_products=non_purchate_products["ProductName"]
non_purchate_products
# Out:
# 0                 Butter - Unsalted
# 3      Soup - Campbells Bean Medley
# 4     Wine - Blue Nun Qualitatswein
# 1     Wine - Ej Gallo Sierra Valley
# 41                      Beans - Wax
# Name: ProductName, dtype: object

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
product_recomentdations={}

# %%
customer_list=total_quantity['CustomerID'].unique().tolist()

# %%
for customer in customer_list:
    #take list of products of more similar customers
    customer=customer
    customer_recomend=distance[customer].sort_values(ascending=False)[1:6]
    total_quantity_example=total_quantity[total_quantity['CustomerID'].isin(customer_recomend.index)]
    total_quantity_by_product=total_quantity_example.groupby(['ProductName'],
                                                            as_index=False).agg({'Quantity':'sum'})
    total_quantity_by_product=total_quantity_by_product.sort_values('Quantity',ascending=False)
    
    #filtering by top products no purchated by the customer
    total_quantity_example_purchate=total_quantity[total_quantity["CustomerID"]==customer]
    all_products=pd.merge(total_quantity_by_product,total_quantity_example_purchate,how="left",on="ProductName")
    non_purchate_products=all_products[all_products['Quantity_y'].isnull()].sort_values('Quantity_x',
                                                                                        ascending=False)[0:5]
    non_purchate_products=non_purchate_products["ProductName"]
    
    product_recomentdations[customer]= list(non_purchate_products.values)

# %%
product_recomentdations
# Out:
# {33: ['Butter - Unsalted',
#   'Soup - Campbells Bean Medley',
#   'Wine - Blue Nun Qualitatswein',
#   'Wine - Ej Gallo Sierra Valley',
#   'Beans - Wax'],
#  200: ['Soup - Campbells Bean Medley',
#   'Bay Leaf',
#   'Pork - Kidney',
#   'Wanton Wrap',
#   'Muffin - Carrot Individual Wrap'],
#  264: ['Soupfoamcont12oz 112con',
#   'Bread - Italian Roll With Herbs',
#   'Veal - Inside, Choice',
#   'Fish - Scallops, Cold Smoked',
#   'Fondant - Icing'],
#  356: ['Butter - Unsalted',
#   'Veal - Inside, Choice',
#   'Beets - Candy Cane, Organic',
#   'Nut - Chestnuts, Whole',
#   'Wasabi Powder'],
#  412: ['Olive - Spread Tapenade',
#   'Wine - Blue Nun Qualitatswein',
#   'Pepper - Black, Whole',
#   'Soup - Campbells Bean Medley',
#   'Sauce - Gravy, Au Jus, Mix'],
#  464: ['Butter - Unsalted',
#   'Pepper - Black, Whole',
#   'Peas - Pigeon, Dry',
#   'Bar - Granola Trail Mix Fruit Nut',
#   'Veal - Inside, Choice'],
#  477: ['Olive - Spread Tapenade',
# ...

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
recom_product_df=pd.DataFrame.from_dict(product_recomentdations).T
recom_product_df
# Out:
#                                    0                                1  \
# 33                 Butter - Unsalted     Soup - Campbells Bean Medley
# 200     Soup - Campbells Bean Medley                         Bay Leaf
# 264          Soupfoamcont12oz 112con  Bread - Italian Roll With Herbs
# 356                Butter - Unsalted            Veal - Inside, Choice
# 412          Olive - Spread Tapenade    Wine - Blue Nun Qualitatswein
# ...                              ...                              ...
# 97928       Soup - Campbells, Lentil             Cheese - Brie,danish
# 98069                Skirt - 29 Foot         Cheese - Taleggio D.o.p.
# 98159  Chips Potato Salt Vinegar 43g  Wine - Red, Harrow Estates, Cab
# 98185                Crackers - Trio                           Pernod
# 98200                    Beans - Wax                     Sherry - Dry
#
#                                    2                              3  \
# ...

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
distance= pd.DataFrame(1/(1 + squareform(pdist(data_T, 'correlation'))),index=data_pivotTable.columns,
                       columns=data_pivotTable.columns)
distance
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.493776  0.529677  0.510360  0.506951  0.507217
# 200         0.493776  1.000000  0.499733  0.498575  0.482172  0.481921
# 264         0.529677  0.499733  1.000000  0.497579  0.513573  0.490305
# 356         0.510360  0.498575  0.497579  1.000000  0.490143  0.489778
# 412         0.506951  0.482172  0.513573  0.490143  1.000000  0.497577
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.479764  0.484514  0.525278  0.496086  0.500064  0.507963
# 98069       0.493197  0.534491  0.511845  0.484207  0.481259  0.484219
# 98159       0.486457  0.500253  0.503500  0.502204  0.502418  0.499195
# 98185       0.491384  0.484272  0.515736  0.506401  0.505997  0.489667
# 98200       0.492072  0.488735  0.490875  0.500631  0.515015  0.516325
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# ...

# %%
product_recomentdations_corr={}
for customer in customer_list:
    #take list of products of more similar customers
    customer=customer
    customer_recomend=distance[customer].sort_values(ascending=False)[1:6]
    total_quantity_example=total_quantity[total_quantity['CustomerID'].isin(customer_recomend.index)]
    total_quantity_by_product=total_quantity_example.groupby(['ProductName'],
                                                            as_index=False).agg({'Quantity':'sum'})
    total_quantity_by_product=total_quantity_by_product.sort_values('Quantity',ascending=False)
    
    #filtering by top products no purchated by the customer
    total_quantity_example_purchate=total_quantity[total_quantity["CustomerID"]==customer]
    all_products=pd.merge(total_quantity_by_product,total_quantity_example_purchate,how="left",on="ProductName")
    non_purchate_products=all_products[all_products['Quantity_y'].isnull()].sort_values('Quantity_x',
                                                                                        ascending=False)[0:5]
    non_purchate_products=non_purchate_products["ProductName"]
    
    product_recomentdations_corr[customer]= list(non_purchate_products.values)

# %%
product_recomentdations_corr
# Out:
# {33: ['Knife Plastic - White',
#   'Muffin - Zero Transfat',
#   'Banana Turning',
#   'Crush - Cream Soda',
#   'Veal - Osso Bucco'],
#  200: ['Otomegusa Dashi Konbu',
#   'Crackers - Trio',
#   'Pail With Metal Handle 16l White',
#   'Milk Powder',
#   'Potatoes - Idaho 100 Count'],
#  264: ['Water - Mineral, Natural',
#   'Wine - Toasted Head',
#   'Snapple - Iced Tea Peach',
#   'Pickerel - Fillets',
#   'Garbag Bags - Black'],
#  356: ['Cheese - Taleggio D.o.p.',
#   'Coconut - Shredded, Sweet',
#   'Cheese - Cheddarsliced',
#   'Ocean Spray - Kiwi Strawberry',
#   'Olives - Kalamata'],
#  412: ['Cake - Mini Cheesecake',
#   'Butter - Unsalted',
#   'Salmon - Atlantic, Skin On',
#   'Wine - Hardys Bankside Shiraz',
#   'Gloves - Goldtouch Disposable'],
#  464: ['Bread - Bistro White',
#   'Knife Plastic - White',
#   'Wonton Wrappers',
#   'Broom - Corn',
#   'Meldea Green Tea Liquor'],
#  477: ['Olive - Spread Tapenade',
#   'Squid U5 - Thailand',
#   'Apricots Fresh',
# ...

# %%
recom_product_corr_df=pd.DataFrame.from_dict(product_recomentdations_corr).T
recom_product_corr_df
# Out:
#                                 0                              1  \
# 33          Knife Plastic - White         Muffin - Zero Transfat
# 200         Otomegusa Dashi Konbu                Crackers - Trio
# 264      Water - Mineral, Natural            Wine - Toasted Head
# 356      Cheese - Taleggio D.o.p.      Coconut - Shredded, Sweet
# 412        Cake - Mini Cheesecake              Butter - Unsalted
# ...                           ...                            ...
# 97928           Lettuce - Treviso     Yogurt - Blueberry, 175 Gr
# 98069  Wine - Red, Colio Cabernet                  Veal - Inside
# 98159                  Water, Tap                        Bananas
# 98185    Cheese - Taleggio D.o.p.            Squid U5 - Thailand
# 98200              Juice - Orange  Pork - Hock And Feet Attached
#
#                                       2                              3  \
# 33                       Banana Turning             Crush - Cream Soda
# ...
