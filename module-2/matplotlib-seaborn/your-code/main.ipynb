# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'r+')
plt.show()

# %%
plt.plot(x,z,color='green', marker='*')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axs = plt.subplots(ncols=2, nrows=1)
axs[0].plot(x, y)
axs[1].plot(x, z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y)
axs[1].plot(x, z)
axs[0].set_title('plot: x vs 2x')
axs[1].set_title('plot: x vs x^2')
axs[0].set_xlabel('x')
axs[0].set_ylabel('2x')
axs[1].set_xlabel('x')
axs[1].set_ylabel('x^2')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = x**2
y2 = np.exp(x)

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y1)
axs[1].plot(x, y2)
axs[1].set_xscale('log')
axs[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y1, label='x^2', color='blue')
axs[1].plot(x, y2, label='e^x', color='green')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[0].legend(loc=2, prop={'size': 10})
axs[1].legend(loc=2, prop={'size': 10})
axs[0].set_title('plot: x vs 2x')
axs[1].set_title('plot: x vs e^x')
axs[0].set_xlabel('x')
axs[0].set_ylabel('x^2')
axs[1].set_xlabel('x')
axs[1].set_ylabel('e^x')
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2=pd.read_csv('../data/fitbit2.csv')
fitbit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#calculating new columns
# MEDIAN STEPS BY MONTH_ENCODED
fitbit2['Date'] = pd.to_datetime(fitbit2['Date'], format='%Y-%m-%d')
fitbit2['Year'] = pd.DatetimeIndex(fitbit2['Date']).year
fitbit2['Month'] = pd.DatetimeIndex(fitbit2['Date']).month
# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit2['Day of Week'] =fitbit2['Date'].dt.dayofweek
fitbit2['Day Type'] = np.where(fitbit2['Day of Week']<5, 
    'Week day', 
    'Weekend day'
)
fitbit2.sort_values('Month',ascending=True)
# Out:
#           Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 244 2016-01-07            3146  11098      8.25      15            720.000
# 245 2016-01-08            3174  12395      9.23       2            567.000
# 268 2016-01-31            2787    626      4.65       0            671.000
# 267 2016-01-30            3034   9774      7.26       0            519.000
# 266 2016-01-29            2931   9952      7.39      17            760.000
# ..         ...             ...    ...       ...     ...                ...
# 209 2015-12-03            3165  10784      8.04      14            774.000
# 208 2015-12-02            3125  10745      8.01      10            634.000
# 207 2015-12-01            3232   1681     12.49      14            750.000
# 223 2015-12-17            2709   8371      6.22      18              1.069
# 212 2015-12-06            3072  12738      9.46      10            811.000
#
# ...

# %%
# grouping data
#MEDIAN STEPS BY MONTH_ENCODED
fitbit2['Month Name'] =pd.to_datetime(fitbit2['Month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
steps_by_month=fitbit2.groupby(['Month','Month Name']).agg({'Steps':'mean'})
steps_by_month
# Out:
#                          Steps
# Month Month Name
# 1     Jan          9892.064516
# 2     Feb          8922.866667
# 3     Mar         10312.935484
# 4     Apr         13079.033333
# 5     May         10620.096774
# 6     Jun         12536.166667
# 7     Jul          9193.322581
# 8     Aug         11584.774194
# 9     Sep          9191.333333
# 10    Oct          8272.451613
# 11    Nov          9467.466667
# 12    Dec          8470.064516

# %%
steps_by_month.reset_index(drop=False, inplace=True)
steps_by_month
# Out:
#     Month Month Name         Steps
# 0       1        Jan   9892.064516
# 1       2        Feb   8922.866667
# 2       3        Mar  10312.935484
# 3       4        Apr  13079.033333
# 4       5        May  10620.096774
# 5       6        Jun  12536.166667
# 6       7        Jul   9193.322581
# 7       8        Aug  11584.774194
# 8       9        Sep   9191.333333
# 9      10        Oct   8272.451613
# 10     11        Nov   9467.466667
# 11     12        Dec   8470.064516

# %%
# grouping data
# MEDIAN STEPS BY WORK_OR_WEEKEND
steps_by_day_type=fitbit2.groupby(['Day Type']).agg({'Steps':'mean'})
steps_by_day_type.reset_index(drop=False, inplace=True)
steps_by_day_type
# Out:
#       Day Type         Steps
# 0     Week day  10144.572519
# 1  Weekend day  10064.238095

# %%
pie_chart_label=list(steps_by_day_type['Day Type'].unique())

# %%
# building vis
# MEDIAN STEPS BY MONTH_ENCODED
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(12,4))
axs[0].plot(steps_by_month['Month Name'], steps_by_month['Steps'], label='Steps', color='blue')
axs[0].set_title('Average number of steps change by month')
axs[0].legend(loc=2, prop={'size': 10})
# MEDIAN STEPS BY WORK_OR_WEEKEND
explode = (0, 0.1, 0)
axs[1].pie(steps_by_day_type['Steps'], autopct='%1.1f%%', shadow=True, startangle=90, labels=pie_chart_label)
axs[1].set_title('Average number of steps change by day type')
plt.show()

# %%
#saving fig
fig.savefig('../figures/Fitbit.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
plt.scatter(fitbit2['Minutes Lightly Active'], fitbit2['Steps'], marker='x',label='Minutes Lightly Active vs Steps')
plt.scatter(fitbit2['Minutes Very Active'], fitbit2['Steps'], marker='x',label='Minutes Very Active vs Steps')
plt.scatter(fitbit2['Minutes Sedentary'], fitbit2['Steps'], marker='x',label='Minutes Sedentary vs Steps')
plt.legend()
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=[object])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=[object])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))
ax.hist(titanic['Age'], bins=10)
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
bins_cut = pd.cut(titanic['Age'], [0, 10, 20, 50, 100])
age=titanic.groupby(bins_cut)['Age'].agg(['count'])
age.plot(kind='bar',figsize=(12,6))
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# We can see which is the most frequent age, changing the bin size we can see in more or less detil the age groups.
# For example, in the second chart we see that most of the people is between 20 and 50 years old. However, if we split
# the age in smaller bins we can see that there are more people between 20 and 30 than between 40 and 50.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
dis=sns.displot(x="Age", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender=titanic.groupby(['Gender']).count()
axs = gender['PassengerId'].plot(kind="bar",figsize=(12,6))
plt.show()

# %%
# Method 2 - seaborn
# your code here
axs = sns.displot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
gender=titanic.groupby(['Pclass']).count()
axs = gender['PassengerId'].plot(kind="bar",figsize=(12,6))
plt.show()

# %%
# Method 2 - seaborn
# your code here
axs = sns.displot(x="Pclass", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
age=titanic['Age'].describe()
ax = age.plot(kind="bar",figsize=(12,6))

# %%
ax.set_xticklabels(age)
# Out:
# [Text(0, 0, '1309.0'),
#  Text(1, 0, '29.879185698255316'),
#  Text(2, 0, '13.448335449444754'),
#  Text(3, 0, '0.17'),
#  Text(4, 0, '22.0'),
#  Text(5, 0, '28.5'),
#  Text(6, 0, '37.0'),
#  Text(7, 0, '80.0')]

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %% [markdown]
# Most people is above the 75% which means that most people is pretty young

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
axs=sns.displot(titanic['Age'], discrete = True, kde = True)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %% [markdown]
# We can see in detail the number of people that belongs to each age group, also we see distribution very clearly

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.plot(titanic['Age'], titanic['Fare'],'.')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.regplot(data=titanic, x='Age', y='Fare', scatter=False);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
ax = sns.heatmap(titanic[['Age', 'Fare']].corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# Age and pcclass

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
Age_Pclass=titanic[['Age','Pclass']]

# %%
dis=sns.displot(Age_Pclass, x="Age", hue="Pclass")

# %% [markdown]
# We see that young people were in class 3 while class 1 was more popular for old peope (they tent to have more money)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
gender_age=titanic[['Gender','Age']]

# %%
dis=sns.displot(gender_age, x="Age", hue="Gender")
