# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'r+')
plt.show()

# %%
plt.plot(x,z,color='green', marker='*')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axs = plt.subplots(ncols=2, nrows=1)
axs[0].plot(x, y)
axs[1].plot(x, z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y)
axs[1].plot(x, z)
axs[0].set_title('plot: x vs 2x')
axs[1].set_title('plot: x vs x^2')
axs[0].set_xlabel('x')
axs[0].set_ylabel('2x')
axs[1].set_xlabel('x')
axs[1].set_ylabel('x^2')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = x**2
y2 = np.exp(x)

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y1)
axs[1].plot(x, y2)
axs[1].set_xscale('log')
axs[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
axs[0].plot(x, y1, label='x^2', color='blue')
axs[1].plot(x, y2, label='e^x', color='green')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[0].legend(loc=2, prop={'size': 10})
axs[1].legend(loc=2, prop={'size': 10})
axs[0].set_title('plot: x vs 2x')
axs[1].set_title('plot: x vs e^x')
axs[0].set_xlabel('x')
axs[0].set_ylabel('x^2')
axs[1].set_xlabel('x')
axs[1].set_ylabel('e^x')
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2=pd.read_csv('../data/fitbit2.csv')
fitbit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#calculating new columns
# MEDIAN STEPS BY MONTH_ENCODED
fitbit2['Date'] = pd.to_datetime(fitbit2['Date'], format='%Y-%m-%d')
fitbit2['Year'] = pd.DatetimeIndex(fitbit2['Date']).year
fitbit2['Month'] = pd.DatetimeIndex(fitbit2['Date']).month
# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit2['Day of Week'] =fitbit2['Date'].dt.dayofweek
fitbit2['Day Type'] = np.where(fitbit2['Day of Week']<5, 
    'Week day', 
    'Weekend day'
)
fitbit2.sort_values('Month',ascending=True)
# Out:
#           Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 244 2016-01-07            3146  11098      8.25      15            720.000
# 245 2016-01-08            3174  12395      9.23       2            567.000
# 268 2016-01-31            2787    626      4.65       0            671.000
# 267 2016-01-30            3034   9774      7.26       0            519.000
# 266 2016-01-29            2931   9952      7.39      17            760.000
# ..         ...             ...    ...       ...     ...                ...
# 209 2015-12-03            3165  10784      8.04      14            774.000
# 208 2015-12-02            3125  10745      8.01      10            634.000
# 207 2015-12-01            3232   1681     12.49      14            750.000
# 223 2015-12-17            2709   8371      6.22      18              1.069
# 212 2015-12-06            3072  12738      9.46      10            811.000
#
# ...

# %%
# grouping data
#MEDIAN STEPS BY MONTH_ENCODED
fitbit2['Month Name'] =pd.to_datetime(fitbit2['Month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
steps_by_month=fitbit2.groupby(['Month','Month Name']).agg({'Steps':'mean'})
steps_by_month
# Out:
#                          Steps
# Month Month Name
# 1     Jan          9892.064516
# 2     Feb          8922.866667
# 3     Mar         10312.935484
# 4     Apr         13079.033333
# 5     May         10620.096774
# 6     Jun         12536.166667
# 7     Jul          9193.322581
# 8     Aug         11584.774194
# 9     Sep          9191.333333
# 10    Oct          8272.451613
# 11    Nov          9467.466667
# 12    Dec          8470.064516

# %%
steps_by_month.reset_index(drop=False, inplace=True)
steps_by_month
# Out:
#     Month Month Name         Steps
# 0       1        Jan   9892.064516
# 1       2        Feb   8922.866667
# 2       3        Mar  10312.935484
# 3       4        Apr  13079.033333
# 4       5        May  10620.096774
# 5       6        Jun  12536.166667
# 6       7        Jul   9193.322581
# 7       8        Aug  11584.774194
# 8       9        Sep   9191.333333
# 9      10        Oct   8272.451613
# 10     11        Nov   9467.466667
# 11     12        Dec   8470.064516

# %%
# grouping data
# MEDIAN STEPS BY WORK_OR_WEEKEND
steps_by_day_type=fitbit2.groupby(['Day Type']).agg({'Steps':'mean'})
steps_by_day_type.reset_index(drop=False, inplace=True)
steps_by_day_type
# Out:
#       Day Type         Steps
# 0     Week day  10144.572519
# 1  Weekend day  10064.238095

# %%
pie_chart_label=list(steps_by_day_type['Day Type'].unique())

# %%
# building vis
# MEDIAN STEPS BY MONTH_ENCODED
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(12,4))
axs[0].plot(steps_by_month['Month Name'], steps_by_month['Steps'], label='Steps', color='blue')
axs[0].set_title('Average number of steps change by month')
axs[0].legend(loc=2, prop={'size': 10})
# MEDIAN STEPS BY WORK_OR_WEEKEND
explode = (0, 0.1, 0)
axs[1].pie(steps_by_day_type['Steps'], autopct='%1.1f%%', shadow=True, startangle=90, labels=pie_chart_label)
axs[1].set_title('Average number of steps change by day type')
plt.show()

# %%
#saving fig
fig.savefig('../figures/Fitbit.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
